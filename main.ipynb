# %% [markdown]
# # Introduction
#
# This notebook serves as a journal for learning `folium`.

# %%
import folium
import geopandas as gpd
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[6], line 2
#       1 import folium
# ----> 2 import geopandas as gpd
#
# ModuleNotFoundError: No module named 'geopandas'

# %%
SG_CENTER = [1.3521, 103.8198]

# %% [markdown]
# # Adding a Map

# %%
m = folium.Map(location=SG_CENTER,
               tiles="cartodb positron")
m.save("maps/index.html")

# %% [markdown]
# # Adding Markers
